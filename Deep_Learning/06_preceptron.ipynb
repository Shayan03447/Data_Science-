# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('./Data_Set/Single Layer Perceptron Dataset.csv')
df.head()
# Out:
#    Pattern  Feature1  Feature2  Feature3  Class_Label
# 0      1.0       1.0      0.08      0.72          1.0
# 1      2.0       1.0      0.10      1.00          1.0
# 2      3.0       1.0      0.26      0.58          1.0
# 3      4.0       1.0      0.35      0.95          0.0
# 4      5.0       1.0      0.45      0.15          1.0

# %%
df.isnull().sum()
# Out:
# Pattern        1
# Feature1       1
# Feature2       1
# Feature3       1
# Class_Label    1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Pattern  Feature1  Feature2  Feature3  Class_Label
# 0       1.0       1.0      0.08      0.72          1.0
# 1       2.0       1.0      0.10      1.00          1.0
# 2       3.0       1.0      0.26      0.58          1.0
# 3       4.0       1.0      0.35      0.95          0.0
# 4       5.0       1.0      0.45      0.15          1.0
# 5       6.0       1.0      0.60      0.30          1.0
# 6       7.0       1.0      0.70      0.65          0.0
# 7       8.0       1.0      0.92      0.45          0.0
# 8       9.0       1.0      0.42      0.85          0.0
# 9      10.0       1.0      0.65      0.55          0.0
# 10     11.0       1.0      0.20      0.30          1.0
# 11     12.0       1.0      0.20      1.00          0.0
# 12     13.0       1.0      0.85      0.10          1.0

# %%
X=df.iloc[:,0:4]
X
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
y=df.iloc[:,-1]
y
type(y)
# Out:
# pandas.core.series.Series

# %%
plt.scatter(X['Feature1'], X['Feature2'],c=y,cmap='winter',s=200)

# %%
X=np.insert(X,0,1,axis=1)
X
# Out:
# array([[ 1.  ,  1.  ,  1.  ,  0.08,  0.72],
#        [ 1.  ,  2.  ,  1.  ,  0.1 ,  1.  ],
#        [ 1.  ,  3.  ,  1.  ,  0.26,  0.58],
#        [ 1.  ,  4.  ,  1.  ,  0.35,  0.95],
#        [ 1.  ,  5.  ,  1.  ,  0.45,  0.15],
#        [ 1.  ,  6.  ,  1.  ,  0.6 ,  0.3 ],
#        [ 1.  ,  7.  ,  1.  ,  0.7 ,  0.65],
#        [ 1.  ,  8.  ,  1.  ,  0.92,  0.45],
#        [ 1.  ,  9.  ,  1.  ,  0.42,  0.85],
#        [ 1.  , 10.  ,  1.  ,  0.65,  0.55],
#        [ 1.  , 11.  ,  1.  ,  0.2 ,  0.3 ],
#        [ 1.  , 12.  ,  1.  ,  0.2 ,  1.  ],
#        [ 1.  , 13.  ,  1.  ,  0.85,  0.1 ]])

# %%
np.ones(X.shape[1])
# Out:
# array([1., 1., 1., 1., 1.])

# %%
def step(z):
    return 1 if z >= 0 else 0

def Perceptron(X,y):
    X=np.insert(X,0,1,axis=1)
    weights=np.ones(X.shape[1])
    lr=0.1
    
    for i in range(1000):
        j=np.random.randint(0,X.shape[0])
        y_hat=step(np.dot(X[j],weights))
        weights=weights+lr*(y[j]-y_hat)*X[j]
    return weights[0],weights[1:]

# %%
intercept_,coef_=Perceptron(X,y)

# %%
print(intercept_)
print(coef_)
# Out:
# 1.5000000000000004
# [ 1.5    0.1    1.5   -1.77  -4.121]

# %% [markdown]
# For ploting graph

# %% [markdown]
# m=-a/b
# b=-(intercept_/corf_[1])

# %%
m=-(coef_[0]/coef_[1])
b=-(intercept_/coef_[1])

# %%
x_input=np.linspace(-3,3,100)
y_input=m*x_input+b

# %%
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
