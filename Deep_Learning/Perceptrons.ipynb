# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('./Data_Set/Single Layer Perceptron Dataset.csv')
df.head()
df.shape
# Out:
# (14, 5)

# %%
plt.scatter(df['Pattern'],df['Feature1'])

# %%
df.isnull().sum()
# Out:
# Pattern        1
# Feature1       1
# Feature2       1
# Feature3       1
# Class_Label    1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
X=df.drop(['Class_Label'],axis=1)
X
# Out:
#     Pattern  Feature1  Feature2  Feature3
# 0       1.0       1.0      0.08      0.72
# 1       2.0       1.0      0.10      1.00
# 2       3.0       1.0      0.26      0.58
# 3       4.0       1.0      0.35      0.95
# 4       5.0       1.0      0.45      0.15
# 5       6.0       1.0      0.60      0.30
# 6       7.0       1.0      0.70      0.65
# 7       8.0       1.0      0.92      0.45
# 8       9.0       1.0      0.42      0.85
# 9      10.0       1.0      0.65      0.55
# 10     11.0       1.0      0.20      0.30
# 11     12.0       1.0      0.20      1.00
# 12     13.0       1.0      0.85      0.10

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     0.0
# 4     1.0
# 5     1.0
# 6     0.0
# 7     0.0
# 8     0.0
# 9     0.0
# 10    1.0
# 11    0.0
# 12    1.0
# Name: Class_Label, dtype: float64

# %%
from sklearn.linear_model import Perceptron

# %%
p=Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 3.  ,  7.  , -0.21, -2.45]])

# %% [markdown]
# The equation is w1x1+w2x2+w3x3....wdxd
#
# w1=3.  , w2=7.  ,w3=-0.21  ,w4 = -2.45

# %%
p.intercept_
# Out:
# array([7.])

# %% [markdown]
# The value of b is 7
